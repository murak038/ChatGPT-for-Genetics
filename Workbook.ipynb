# %%
import openai
from langchain.llms import OpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory

import os
import re
import json
import requests
import openai
from datetime import datetime

# %%
OPEN_AI_KEY = ''
openai.api_key = OPEN_AI_KEY

# %%
def query_chatgpt(prompt):
    response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",
          messages=[
                {"role": "system", "content": "You are an expert assistant that can turn user queries into GraphQL queries."},
                {"role": "user", "content": prompt}
            ],
          temperature=0,
          max_tokens=1024,
          top_p=1,
          frequency_penalty=0,
          presence_penalty=0,
            stop=["###"],
        )
    response_text = response.choices[0].message['content']
    return response_text

# swap the chatGPT model to enable extra long context
def query_chatgpt_16k(prompt):
    response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo-16k",
          messages=[
                {"role": "system", "content": "You are an expert assistant that can turn user queries into GraphQL queries."},
                {"role": "user", "content": prompt}
            ],
          temperature=0,
          max_tokens=1024,
          top_p=1,
          frequency_penalty=0,
          presence_penalty=0,
            stop=["###"],
        )
    response_text = response.choices[0].message['content']
    return response_text

def query_langchain(llm, prompt):
    response = llm.predict(input=prompt)
    return response

def query_graphql(query_string):
    error_message, hits_list = None, None
    # Set base URL of GraphQL API endpoint
    base_url = "https://api.platform.opentargets.org/api/v4/graphql"

    # Perform POST request and check status code of response
    # This handles the cases where the Open Targets API is down or our query is invalid
    try:
        response = requests.post(base_url, json={"query": query_string})
        response.raise_for_status()
    except requests.exceptions.HTTPError as err:
        a = 1
    # Transform API response from JSON into Python dictionary and print in console
    api_response = json.loads(response.text)
    if 'data' not in api_response:
        error_message = api_response
        print('ERROR:\n {}\n\n'.format(error_message))
    elif api_response['data']==None:
        error_message = api_response['errors'][0]['message']
        print('ERROR:\n {}\n\n'.format(error_message))
    else:
        try:
            hits_list = api_response["data"]["search"]["hits"][0]
        except:
            print(api_response)
    
    return error_message, hits_list

def convert_json_response(hits_list, user_input):
    response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo-16k",
          messages=[
                {"role": "system", "content": "You are an helpful assistant."},
                {"role": "user", "content": "Given the following json response, answer the question as a list. Json Response:\n{}\n\nQuestion:\n{}".format(hits_list, user_input)}
            ],
          temperature=0,
          max_tokens=1024,
          top_p=1,
          frequency_penalty=0,
          presence_penalty=0,
            stop=["###"],
        )
    response_text = response.choices[0].message['content']
    return response_text

# %%
user_inputs = ["Find the top 2 diseases linked to HBB", "What are the top 3 diseases associated with ABCA4?", "What are the targets of vorinostat?", "Find drugs that are used for treating ulcerative colitis.", "Which diseases are associated with the genes targetted by fasudil?", "Show all the diseases that have at least 5 pathways associated with Alzheimer"]

# %%
# read prompt template file
with open("graphql_schema.txt", "r") as f:
    prompt_template = f.read()

# read in GraphQL schema
with open("graphql_real_schema.txt", "r") as f:
    schema = f.read()

# Prime the target query for completion
prime_prompt = "query top_n_associated_diseases {\n  search(queryString:"

# %% [markdown]
# ## Lets start with the simplest approach.

# %%
# Custom input by the user
# user_input = "Find the top 2 diseases associated with BRCA1"
# user_input = input("How can I help you today?\n")

for user_input in user_inputs:
    print('-'*100)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    prompt = "Given the following example, create the GraphQL query to answer the following user input.\n\nExample: \n{}\n\nUser Input: {}\n\nGenerated Query:\n".format(prompt_template, user_input)    
    response = query_chatgpt(prompt)
    query_string =  response
    print('QUERY:\n {}\n\n'.format(query_string))

    error_message, hits_list = query_graphql(query_string)

    response_text = convert_json_response(hits_list, user_input)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# QUERY:
#  query top_n_associated_diseases {
#     search(queryString: "HBB", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 2}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# ANSWER:
# 1. Beta-thalassemia HBB/LCRB
# 2. Sickle cell anemia
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# QUERY:
#  query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# ANSWER:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# QUERY:
#  query targets_of_drug {
#   search(queryString: "vorinostat", entityNames: "drug") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           targets {
#             id
#             name
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'targets' on type 'Drug'. (line 9, column 11):
#           targets {
#           ^
#
#
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with the targets of vorinostat. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# QUERY:
#  query drugs_for_ulcerative_colitis {
#   search(queryString: "ulcerative colitis", entityNames: "disease") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           treatments {
#             rows {
#               treatment {
#                 name
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'treatments' on type 'Disease'. Did you mean 'parents'? (line 9, column 11):
#           treatments {
#           ^
#
#
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with a list of drugs used for treating ulcerative colitis. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
#
# QUERY:
#  query diseases_associated_with_genes {
#   search(queryString: "fasudil", entityNames: "drug") {
#     hits {
#       id
#       name
#       object {
#         ... on Drug {
#           targets {
#             id
#             name
#             associatedDiseases {
#               rows {
#                 disease {
#                   name
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'targets' on type 'Drug'. (line 8, column 11):
#           targets {
#           ^
#
#
# ANSWER:
# Since the provided JSON response is None, there is no information available to answer the question about diseases associated with the genes targeted by fasudil.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Show all the diseases that have at least 5 pathways associated with Alzheimer
#
# QUERY:
#  query diseases_with_pathways {
#   search(queryString: "Alzheimer", entityNames: "disease") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           pathways(page: {index: 0, size: 5}) {
#             rows {
#               score
#               pathway {
#                 name
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'pathways' on type 'Disease'. (line 9, column 11):
#           pathways(page: {index: 0, size: 5}) {
#           ^
#
#
# ANSWER:
# Unfortunately, the given JSON response is empty, so there is no information available to answer the question.

# %% [markdown]
# ### Analysis:
# This approach works well for the simple queries given in the repo, but quickly falters when exploring complex queries such as `Find drugs that are used for treating ulcerative colitis.` The main error appears to be that the ChatGPT model creates fields or gets fields incorrectly, since the model isn't grounding the query generation within the schema of the database.

# %% [markdown]
# ## Grounding Output in DB Schema

# %%
for user_input in user_inputs:
    print('-'*100)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    prompt = "Given the following schema and example, create the GraphQL query to answer the following user input.\n\nSchema:\n{}\n\nExample: \n{}\n\nUser Input: {}\n\nGenerated Query:\n".format(schema, prompt_template, user_input)
    query_string = query_chatgpt_16k(prompt)
    print('QUERY:\n {}\n\n'.format(query_string))

    error_message, hits_list = query_graphql(query_string)

    response_text = convert_json_response(hits_list, user_input)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# QUERY:
#  query top_n_linked_diseases {
#   search(queryString: "HBB", entityNames: "target") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Target {
#           linkedDiseases {
#             rows(size: 2) {
#               name
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'linkedDiseases' on type 'Target'. Did you mean 'associatedDiseases'? (line 9, column 11):
#           linkedDiseases {
#           ^
#
#
# ANSWER:
# Unfortunately, without the actual JSON response, I am unable to provide a list of the top 2 diseases linked to HBB. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# QUERY:
#  query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with the top 3 diseases associated with ABCA4. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# QUERY:
#  query targets_of_drug {
#   search(queryString: "vorinostat", entityNames: ["drug"]) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           linkedTargets {
#             rows {
#               target {
#                 id
#                 approvedSymbol
#                 approvedName
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with the targets of vorinostat. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# QUERY:
#  query drugs_for_treating_disease {
#   search(queryString: "ulcerative colitis", entityNames: ["disease"]) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           knownDrugs {
#             rows {
#               drug {
#                 id
#                 name
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ANSWER:
# - Sulfasalazine
# - Budesonide
# - Doxycycline Anhydrous
# - Adalimumab
# - Golimumab
# - Prednisone
# - Vedolizumab
# - Methylprednisolone
# - Mesalamine
# - Betamethasone Sodium Phosphate
# - Infliximab
# - Balsalazide
# - Tofacitinib
# - Olsalazine
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
#
# QUERY:
#  query diseases_associated_with_genes {
#   search(queryString: "fasudil", entityNames: "drug") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           linkedTargets {
#             rows {
#               target {
#                 associatedDiseases {
#                   rows {
#                     disease {
#                       name
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ANSWER:
# Since the provided JSON response is None, there is no information available to answer the question about diseases associated with the genes targeted by fasudil.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Show all the diseases that have at least 5 pathways associated with Alzheimer
#
# QUERY:
#  query diseases_with_pathways {
#   search(queryString: "Alzheimer", entityNames: "disease") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           pathways {
#             pathway
#             pathwayId
#             topLevelTerm
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'pathways' on type 'Disease'. (line 9, column 11):
#           pathways {
#           ^
#
#
# ANSWER:
# Unfortunately, the given JSON response is empty, so there is no information available to answer the question.

# %% [markdown]
# ### Analysis:
# The model performs better on the question `Find drugs that are used for treating ulcerative colitis.` However, we still see the model's output still doesn't fit into the schema perfectly, resulting in errors. This might be due to the fact that ChatGPT's performance decreases as we use inputs over 8,000 tokens.

# %% [markdown]
# ## What if we used ChatGPT to create a consolidated schema and used it to generate the model's output.

# %%
for user_input in user_inputs:
    print('-'*100)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    # create the prompt
    prompt = "Given the following schema, create the consolidated the GraphQL schema to only include fields that can be used to answer the following user input. The consolidated schema should only contains fields from the original schema that are useful in the generation of an answer to the user input.\n\nSchema:\n{}\n\nUser Input:\n{}\n\nConsolidated Schema:\n".format(schema, user_input)
    
    response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo-16k",
          messages=[
                {"role": "system", "content": "You are an helpful assistant with extensive knowledge of GraphQL and the Open Targets database"},
                {"role": "user", "content": prompt}
            ],
          temperature=0,
          max_tokens=1024,
          top_p=1,
          frequency_penalty=0,
          presence_penalty=0,
            stop=["###"],
        )

    consolidated_schema = response.choices[0].message['content']
    # print('Consolidated Schema:\n{}\n'.format(consolidated_schema))
    
    prompt = "Given the following schema and example, create the GraphQL query to answer the following user input.\n\nSchema:\n{}\n\nExample: \n{}\n\nUser Input: {}\n\nGenerated Query:\n".format(consolidated_schema, prompt_template, user_input)
    # print('Prompt:\n{}\n'.format(prompt))
    query_string = query_chatgpt(prompt)
    print('QUERY:\n {}\n\n'.format(query_string))

    error_message, hits_list = query_graphql(query_string)

    response_text = convert_json_response(hits_list, user_input)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# QUERY:
#  query top_n_linked_diseases {
#   disease(efoId: "HBB") {
#     linkedDiseases {
#       rows(page: {index: 0, size: 2}) {
#         name
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'linkedDiseases' on type 'Disease'. (line 3, column 5):
#     linkedDiseases {
#     ^
#
#
# ANSWER:
# Unfortunately, without the actual JSON response, I am unable to provide you with the top 2 diseases linked to HBB. Please provide the JSON response so that I can assist you further.
# Final QUERY:
# Unfortunately, without the actual JSON response, I am unable to provide you with the top 2 diseases linked to HBB. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# QUERY:
#  query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# ANSWER:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# Final QUERY:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# QUERY:
#  query targets_of_drug {
#   search(queryString: "vorinostat", entityNames: "drug") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on ChemicalProbe {
#           targetFromSourceId
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Fragment cannot be spread here as objects of type 'EntityUnionType' can never be of type 'ChemicalProbe'. (line 8, column 9):
#         ... on ChemicalProbe {
#         ^
#
#
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with the targets of vorinostat. Please provide the JSON response so that I can assist you further.
# Final QUERY:
# I'm sorry, but without the actual JSON response, I cannot provide you with the targets of vorinostat. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# QUERY:
#  query drugs_for_ulcerative_colitis {
#   drugs(chemblIds: ["ulcerative colitis"]) {
#     id
#     name
#     tradeNames
#     indications {
#       rows {
#         disease {
#           name
#         }
#       }
#     }
#   }
# }
#
#
# {'data': {'drugs': []}}
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with a list of drugs used for treating ulcerative colitis. Please provide the JSON response so that I can assist you further.
# Final QUERY:
# I'm sorry, but without the actual JSON response, I cannot provide you with a list of drugs used for treating ulcerative colitis. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 27
#      25 prompt = "Given the following schema and example, create the GraphQL query to answer the following user input.\n\nSchema:\n{}\n\nExample: \n{}\n\nUser Input: {}\n\nGenerated Query:\n".format(consolidated_schema, prompt_template, user_input)
#      26 # print('Prompt:\n{}\n'.format(prompt))
# ---> 27 query_string = query_chatgpt(prompt)
#      28 print('QUERY:\n {}\n\n'.format(query_string))
#      30 error_message, hits_list = query_graphql(query_string)
#
# Cell In[3], line 2, in query_chatgpt(prompt)
#       1 def query_chatgpt(prompt):
# ----> 2     response = openai.ChatCompletion.create(
#       3           model="gpt-3.5-turbo",
#       4           messages=[
#       5                 {"role": "system", "content": "You are an expert assistant that can turn user queries into GraphQL queries."},
#       6                 {"role": "user", "content": prompt}
#       7             ],
#       8           temperature=0,
#       9           max_tokens=1024,
#      10           top_p=1,
#      11           frequency_penalty=0,
#      12           presence_penalty=0,
#      13             stop=["###"],
#      14         )
#      15     response_text = response.choices[0].message['content']
#      16     return response_text
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/openai/api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/openai/api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#     527     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/miniconda3/envs/langchain/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysis
# That approach did much worse... Lets roll back the changes.

# %% [markdown]
# ## Error Correction with LangChain

# %%
for user_input in user_inputs:
    chat = OpenAI(temperature=0.2, top_p=0.1 ,openai_api_key=openai.api_key)
    llm = ConversationChain(
        llm=chat, 
        memory=ConversationBufferMemory(), 
        verbose=False
    )
    print('-'*100)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    prompt = "Given the following example, create the GraphQL query to answer the following user input. If a number isn't given, return all possible answers. {}\n\nUser Input: {}\n\nGenerated Query:\n".format(prompt_template, user_input)
    query_string = query_langchain(llm, prompt)

    print('INITIAL QUERY:\n {}\n\n'.format(query_string))
    error_message, hits_list = query_graphql(query_string)
    runs = 0
    
    error_message, hits_list = query_graphql(query_string)
    runs = 0
    while error_message:
        prompt = "The query failed with the following error: {}\n Can you regenerate the query to fix the error? \nRegenerated Query:\n".format(error_message)
        query_string = query_langchain(llm, prompt)
        error_message, hits_list = query_graphql(query_string)
        runs+=1
        if runs==10:
            error_message=None
            break

    response_text = convert_json_response(hits_list, user_input)    
    print(hits_list)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# INITIAL QUERY:
#   query top_n_associated_diseases {
#     search(queryString: "HBB", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 2}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# {'id': 'ENSG00000244734', 'name': 'HBB', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.793993706260743, 'disease': {'name': 'beta-thalassemia HBB/LCRB'}}, {'score': 0.774931251992265, 'disease': {'name': 'sickle cell anemia'}}]}}}
# ANSWER:
# 1. Beta-thalassemia HBB/LCRB
# 2. Sickle cell anemia
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# INITIAL QUERY:
#   query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# {'id': 'ENSG00000198691', 'name': 'ABCA4', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.8341689198627416, 'disease': {'name': 'severe early-childhood-onset retinal dystrophy'}}, {'score': 0.8288074666259394, 'disease': {'name': 'Cone rod dystrophy'}}, {'score': 0.7835075940441717, 'disease': {'name': 'age-related macular degeneration'}}]}}}
# ANSWER:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# INITIAL QUERY:
#   query targets_of_vorinostat {
#     search(queryString: "vorinostat", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               targets {
#                  rows {
#                   score
#                    target {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Cannot query field 'targets' on type 'Target'. (line 8, column 15):
#               targets {
#               ^
#
#
# ERROR:
#  Cannot query field 'associatedTargets' on type 'Target'. Did you mean 'associatedDiseases'? (line 8, column 15):
#               associatedTargets {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'AssociatedDisease'. (line 11, column 20):
#                    target {
#                    ^
#
#
# {'id': 'ENSG00000171720', 'name': 'HDAC3', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.5669897715700565, 'disease': {'name': 'neoplasm'}}, {'score': 0.5397429909321528, 'disease': {'name': 'multiple myeloma'}}, {'score': 0.5281167797105957, 'disease': {'name': 'neurodegenerative disease'}}, {'score': 0.5161689514662866, 'disease': {'name': 'unspecified peripheral T-cell lymphoma'}}, {'score': 0.5112367470391775, 'disease': {'name': 'Cutaneous T-cell lymphoma'}}, {'score': 0.5039631962908891, 'disease': {'name': 'T-cell non-Hodgkin lymphoma'}}, {'score': 0.3921652902487669, 'disease': {'name': 'graft versus host disease'}}, {'score': 0.38292579388164927, 'disease': {'name': 'primary myelofibrosis'}}, {'score': 0.380262012567663, 'disease': {'name': 'viral disease'}}, {'score': 0.3701210148708717, 'disease': {'name': 'lymphoma'}}, {'score': 0.35761793906626343, 'disease': {'name': 'acute myeloid leukemia'}}, {'score': 0.3531540833653817, 'disease': {'name': 'genetic disorder'}}, {'score': 0.35023083627462015, 'disease': {'name': 'breast adenocarcinoma'}}, {'score': 0.3359891523366922, 'disease': {'name': 'lung cancer'}}, {'score': 0.3169137366531992, 'disease': {'name': 'breast cancer'}}, {'score': 0.31163268183323867, 'disease': {'name': 'renal cell carcinoma'}}, {'score': 0.29668129877261334, 'disease': {'name': 'Hodgkins lymphoma'}}, {'score': 0.28898321456898174, 'disease': {'name': 'ovarian cancer'}}, {'score': 0.28624931542943366, 'disease': {'name': 'head and neck squamous cell carcinoma'}}, {'score': 0.27835937669378524, 'disease': {'name': 'endometrial cancer'}}, {'score': 0.27718489101352634, 'disease': {'name': 'mesothelioma'}}, {'score': 0.26959461007668845, 'disease': {'name': 'gastric adenocarcinoma'}}, {'score': 0.25907547813397597, 'disease': {'name': 'angioimmunoblastic T-cell lymphoma'}}, {'score': 0.2231338372658887, 'disease': {'name': 'squamous cell lung carcinoma'}}, {'score': 0.20891842845958888, 'disease': {'name': 'small cell lung carcinoma'}}]}}}
# ANSWER:
# The targets of vorinostat are:
# 1. HDAC3
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# INITIAL QUERY:
#   query drugs_for_ulcerative_colitis {
#     search(queryString: "ulcerative colitis", entityNames: "drug") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Drug {
#               indications(page: {index: 0, size: 5}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Unknown argument 'page' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(page: {index: 0, size: 5}) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'limit' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(limit: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'first' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(first: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'top' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(top: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'limit' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(limit: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'take' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(take: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'first' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(first: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'top' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(top: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'limit' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(limit: 5) {
#                           ^
#
#
# ERROR:
#  Unknown argument 'take' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(take: 5) {
#                           ^
#
#
# None
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with a list of drugs used for treating ulcerative colitis. Please provide the JSON response so that I can assist you further.
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
#
# INITIAL QUERY:
#   query associated_diseases {
#     search(queryString: "fasudil", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# {'id': 'ENSG00000134318', 'name': 'ROCK2', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.5580112081648932, 'disease': {'name': 'open-angle glaucoma'}}, {'score': 0.5570338462445541, 'disease': {'name': 'ocular hypertension'}}, {'score': 0.5478429832481734, 'disease': {'name': 'neurodegenerative disease'}}, {'score': 0.5052279849309224, 'disease': {'name': 'glaucoma'}}, {'score': 0.4715736284706049, 'disease': {'name': 'graft versus host disease'}}, {'score': 0.46605046286448354, 'disease': {'name': 'Fuchs endothelial corneal dystrophy'}}, {'score': 0.40047013678235266, 'disease': {'name': 'mean corpuscular volume'}}, {'score': 0.3761867338373383, 'disease': {'name': 'lymphocyte count'}}, {'score': 0.37367454435923936, 'disease': {'name': 'body height'}}, {'score': 0.3720764692641677, 'disease': {'name': 'myocardial infarction'}}, {'score': 0.3695798546847018, 'disease': {'name': 'low tension glaucoma'}}, {'score': 0.3695798546847018, 'disease': {'name': 'immune system disease'}}, {'score': 0.34449779007508613, 'disease': {'name': 'BMI-adjusted waist-hip ratio'}}, {'score': 0.32747009105961955, 'disease': {'name': 'body fat percentage'}}, {'score': 0.32464439018738533, 'disease': {'name': 'platelet component distribution width'}}, {'score': 0.3201710930473081, 'disease': {'name': 'mean reticulocyte volume'}}, {'score': 0.31328473619297864, 'disease': {'name': 'brain measurement'}}, {'score': 0.31282878665806985, 'disease': {'name': 'cortical thickness'}}, {'score': 0.29525093859405127, 'disease': {'name': 'serum gamma-glutamyl transferase measurement'}}, {'score': 0.27755447086821106, 'disease': {'name': 'cardiovascular disease'}}, {'score': 0.27718489101352634, 'disease': {'name': 'corneal edema'}}, {'score': 0.26644582337094425, 'disease': {'name': 'appendicular lean mass'}}, {'score': 0.2660512016698931, 'disease': {'name': 'low density lipoprotein cholesterol measurement'}}, {'score': 0.2658871320913831, 'disease': {'name': 'basal cell carcinoma'}}, {'score': 0.262697269669774, 'disease': {'name': 'creatinine measurement'}}]}}}
# ANSWER:
# - Open-angle glaucoma
# - Ocular hypertension
# - Neurodegenerative disease
# - Glaucoma
# - Graft versus host disease
# - Fuchs endothelial corneal dystrophy
# - Mean corpuscular volume
# - Lymphocyte count
# - Body height
# - Myocardial infarction
# - Low tension glaucoma
# - Immune system disease
# - BMI-adjusted waist-hip ratio
# - Body fat percentage
# - Platelet component distribution width
# - Mean reticulocyte volume
# - Brain measurement
# - Cortical thickness
# - Serum gamma-glutamyl transferase measurement
# - Cardiovascular disease
# - Corneal edema
# - Appendicular lean mass
# - Low density lipoprotein cholesterol measurement
# - Basal cell carcinoma
# - Creatinine measurement
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Show all the diseases that have at least 5 pathways associated with Alzheimer
#
# INITIAL QUERY:
#   query all_diseases_with_5_pathways {
#     search(queryString: "Alzheimer", entityNames: "disease") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Disease {
#               pathways(page: {index: 0, size: 5}) {
#                  rows {
#                   score
#                    pathway {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Cannot query field 'pathways' on type 'Disease'. (line 8, column 15):
#               pathways(page: {index: 0, size: 5}) {
#               ^
#
#
# ERROR:
#  Cannot query field 'associatedPathways' on type 'Disease'. Did you mean 'associatedTargets'? (line 8, column 15):
#               associatedPathways(page: {index: 0, size: 5}) {
#               ^
#
#
# ERROR:
#  Cannot query field 'name' on type 'Target'. (line 12, column 22):
#                      name
#                      ^
#
#
# ERROR:
#  Cannot query field 'targetName' on type 'Target'. Did you mean 'targetClass' or 'approvedName'? (line 12, column 22):
#                      targetName
#                      ^
#
#
# {'id': 'MONDO_0004975', 'name': 'Alzheimer disease', 'entity': 'disease', 'object': {'associatedTargets': {'rows': [{'score': 0.828933742802346, 'target': {'approvedName': 'amyloid beta precursor protein'}}, {'score': 0.7241430601388238, 'target': {'approvedName': 'presenilin 1'}}, {'score': 0.6972811478504712, 'target': {'approvedName': 'glutamate ionotropic receptor NMDA type subunit 1'}}, {'score': 0.6794149794175904, 'target': {'approvedName': 'cyclin dependent kinase 5'}}, {'score': 0.6788101271141604, 'target': {'approvedName': 'presenilin 2'}}]}}}
# ANSWER:
# - Alzheimer disease

# %% [markdown]
# ### Analysis
# The basic queries work and we can see that the model tries to correct the errors, as the API errors change with every iteration. This is promising. It is better than the original approaches, but the output of the model is definately wrong for some, such as the last question `Show all the diseases that have at least 5 pathways associated with Alzheimer` which outputs `Alzheimer disease` and gene targets. The output for `Find drugs that are used for treating ulcerative colitis.` also differs from previous attempts.

# %% [markdown]
# ## Error Correction with LangChain with Schema Grounding

# %%
for user_input in user_inputs:
    chat = OpenAI(temperature=0.1, top_p=0.1 ,openai_api_key=openai.api_key, model_name='gpt-3.5-turbo-16k')
    llm = ConversationChain(
        llm=chat, 
        memory=ConversationBufferMemory(), 
        verbose=False
    )
    print('-'*50)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    prompt = "Given the following schema and example, create the GraphQL query to answer the following user input. If a number isn't given, return all possible answers.\n\nSchema:\n{}\n\nExample: \n{}\n\nUser Input: {}\n\nGenerated Query:\n".format(schema, prompt_template, user_input)

    query_string = query_langchain(llm, prompt)

    print('INITIAL QUERY:\n {}\n\n'.format(query_string))
    error_message, hits_list = query_graphql(query_string)
    runs = 0
    while error_message:
        prompt = "The query failed with the following error: {}\n Can you regenerate the query to fix the error? \nRegenerated Query:\n".format(error_message)
        query_string = query_langchain(llm, prompt)
        error_message, hits_list = query_graphql(query_string)
        runs+=1
        if runs==10:
            error_message=None
            break

    response_text = convert_json_response(hits_list, user_input)    
    print(hits_list)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# --------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# INITIAL QUERY:
#  query top_n_linked_diseases {
#     search(queryString: "HBB", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               linkedDiseases {
#                  count
#                  rows(page: {index: 0, size: 2}) {
#                   name
#                 }
#               }
#             }
#         }
#      }
#    }
#  }
#
#
# ERROR:
#  Cannot query field 'linkedDiseases' on type 'Target'. Did you mean 'associatedDiseases'? (line 8, column 15):
#               linkedDiseases {
#               ^
#
#
# ERROR:
#  Unknown argument 'page' on field 'rows' of type 'AssociatedDiseases'. (line 10, column 23):
#                  rows(page: {index: 0, size: 2}) {
#                       ^
#
#
# ERROR:
#  Cannot query field 'name' on type 'AssociatedDisease'. (line 11, column 19):
#                   name
#                   ^
#
#
# {'id': 'ENSG00000244734', 'name': 'HBB', 'entity': 'target', 'object': {'associatedDiseases': {'count': 283, 'rows': [{'disease': {'name': 'beta-thalassemia HBB/LCRB'}}, {'disease': {'name': 'sickle cell anemia'}}, {'disease': {'name': 'Beta-thalassemia'}}, {'disease': {'name': 'dominant beta-thalassemia'}}, {'disease': {'name': 'Heinz body anemia'}}, {'disease': {'name': 'hemoglobin M disease'}}, {'disease': {'name': 'hereditary persistence of fetal hemoglobin-sickle cell disease syndrome'}}, {'disease': {'name': 'mean corpuscular volume'}}, {'disease': {'name': 'mean corpuscular hemoglobin concentration'}}, {'disease': {'name': 'Hereditary persistence of fetal hemoglobin - beta-thalassemia'}}, {'disease': {'name': 'erythrocyte count'}}, {'disease': {'name': 'erythrocytosis, familial, 6'}}, {'disease': {'name': 'hematocrit'}}, {'disease': {'name': 'mean corpuscular hemoglobin'}}, {'disease': {'name': 'hemoglobin measurement'}}, {'disease': {'name': 'hemolytic anemia'}}, {'disease': {'name': 'beta-thalassemia intermedia'}}, {'disease': {'name': 'beta-thalassemia major'}}, {'disease': {'name': 'delta-beta-thalassemia'}}, {'disease': {'name': 'hereditary persistence of fetal hemoglobin-beta-thalassemia syndrome'}}, {'disease': {'name': 'Thalassemia'}}, {'disease': {'name': 'reticulocyte count'}}, {'disease': {'name': 'Red cell distribution width'}}, {'disease': {'name': 'mean reticulocyte volume'}}, {'disease': {'name': 'hematologic disease'}}]}}}
# ANSWER:
# The top 2 diseases linked to HBB are:
# 1. Beta-thalassemia HBB/LCRB
# 2. Sickle cell anemia
# --------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# INITIAL QUERY:
#  query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# {'id': 'ENSG00000198691', 'name': 'ABCA4', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.8341689198627416, 'disease': {'name': 'severe early-childhood-onset retinal dystrophy'}}, {'score': 0.8288074666259394, 'disease': {'name': 'Cone rod dystrophy'}}, {'score': 0.7835075940441717, 'disease': {'name': 'age-related macular degeneration'}}]}}}
# ANSWER:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# --------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# INITIAL QUERY:
#  query vorinostat_targets {
#   search(queryString: "vorinostat", entityNames: ["drug"]) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           linkedTargets {
#             rows {
#               target {
#                 id
#                 approvedSymbol
#                 approvedName
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# None
# ANSWER:
# I'm sorry, but without the actual JSON response, I cannot provide you with the targets of vorinostat. Please provide the JSON response so that I can assist you further.
# --------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# INITIAL QUERY:
#  query drugs_for_ulcerative_colitis {
#   search(queryString: "ulcerative colitis", entityNames: ["disease"]) {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           knownDrugs(freeTextQuery: "ulcerative colitis") {
#             rows {
#               drug {
#                 id
#                 name
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# {'id': 'EFO_0000729', 'name': 'ulcerative colitis', 'entity': 'disease', 'object': {'knownDrugs': {'rows': [{'drug': {'id': 'CHEMBL421', 'name': 'SULFASALAZINE'}}, {'drug': {'id': 'CHEMBL1370', 'name': 'BUDESONIDE'}}, {'drug': {'id': 'CHEMBL1433', 'name': 'DOXYCYCLINE ANHYDROUS'}}, {'drug': {'id': 'CHEMBL1201580', 'name': 'ADALIMUMAB'}}, {'drug': {'id': 'CHEMBL1433', 'name': 'DOXYCYCLINE ANHYDROUS'}}, {'drug': {'id': 'CHEMBL1201833', 'name': 'GOLIMUMAB'}}, {'drug': {'id': 'CHEMBL635', 'name': 'PREDNISONE'}}, {'drug': {'id': 'CHEMBL1200699', 'name': 'DOXYCYCLINE'}}, {'drug': {'id': 'CHEMBL1743087', 'name': 'VEDOLIZUMAB'}}, {'drug': {'id': 'CHEMBL1201580', 'name': 'ADALIMUMAB'}}, {'drug': {'id': 'CHEMBL650', 'name': 'METHYLPREDNISOLONE'}}, {'drug': {'id': 'CHEMBL704', 'name': 'MESALAMINE'}}, {'drug': {'id': 'CHEMBL1200762', 'name': 'BETAMETHASONE SODIUM PHOSPHATE'}}, {'drug': {'id': 'CHEMBL704', 'name': 'MESALAMINE'}}, {'drug': {'id': 'CHEMBL1201581', 'name': 'INFLIXIMAB'}}, {'drug': {'id': 'CHEMBL421', 'name': 'SULFASALAZINE'}}, {'drug': {'id': 'CHEMBL635', 'name': 'PREDNISONE'}}, {'drug': {'id': 'CHEMBL704', 'name': 'MESALAMINE'}}, {'drug': {'id': 'CHEMBL655', 'name': 'MIDAZOLAM'}}, {'drug': {'id': 'CHEMBL704', 'name': 'MESALAMINE'}}, {'drug': {'id': 'CHEMBL635', 'name': 'PREDNISONE'}}, {'drug': {'id': 'CHEMBL1200699', 'name': 'DOXYCYCLINE'}}, {'drug': {'id': 'CHEMBL1201346', 'name': 'BALSALAZIDE'}}, {'drug': {'id': 'CHEMBL221959', 'name': 'TOFACITINIB'}}, {'drug': {'id': 'CHEMBL425', 'name': 'OLSALAZINE'}}]}}}
# ANSWER:
# - Sulfasalazine
# - Budesonide
# - Doxycycline Anhydrous
# - Adalimumab
# - Golimumab
# - Prednisone
# - Vedolizumab
# - Methylprednisolone
# - Mesalamine
# - Betamethasone Sodium Phosphate
# - Infliximab
# - Balsalazide
# - Tofacitinib
# - Olsalazine
# --------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
#
# INITIAL QUERY:
#  query associated_diseases {
#   search(queryString: "fasudil", entityNames: "drug") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Drug {
#           chemicalProbes {
#             target {
#               associatedDiseases {
#                 rows {
#                   disease {
#                     name
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'chemicalProbes' on type 'Drug'. (line 9, column 11):
#           chemicalProbes {
#           ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Target'. (line 11, column 15):
#               target {
#               ^
#
#
# None
# ANSWER:
# Since the provided JSON response is None, there is no information available to answer the question about diseases associated with the genes targeted by fasudil.
# --------------------------------------------------
# USER INPUT: Show all the diseases that have at least 5 pathways associated with Alzheimer
#
# INITIAL QUERY:
#  query diseases_with_pathways {
#   search(queryString: "Alzheimer", entityNames: "disease") {
#     hits {
#       id
#       name
#       entity
#       object {
#         ... on Disease {
#           pathways {
#             pathway
#             pathwayId
#             topLevelTerm
#           }
#         }
#       }
#     }
#   }
# }
#
#
# ERROR:
#  Cannot query field 'pathways' on type 'Disease'. (line 9, column 11):
#           pathways {
#           ^
#
#
# {'id': 'MONDO_0004975', 'name': 'Alzheimer disease', 'entity': 'disease', 'object': {'therapeuticAreas': [{'name': 'psychiatric disorder'}, {'name': 'nervous system disease'}], 'directLocations': [], 'indirectLocations': []}}
# ANSWER:
# There are no diseases mentioned in the given json response that have at least 5 pathways associated with Alzheimer.

# %% [markdown]
# ### Analysis
# While the ground helps the model out, it doesn't help the model correct the errors as effectively as hoped. There can be some more work around generating suggestions using the schema.

# %% [markdown]
# ## Schema Informed Suggestions

# %%
for user_input in user_inputs:
    chat = OpenAI(temperature=0.2, top_p=0.1 ,openai_api_key=openai.api_key)
    llm = ConversationChain(
        llm=chat, 
        memory=ConversationBufferMemory(), 
        verbose=False
    )
    print('-'*100)
    print('USER INPUT: {}\n'.format(user_input))
    # create the prompt
    prompt = "Given the following example, create the GraphQL query to answer the following user input. If a number isn't given, return all possible answers. {}\n\nUser Input: {}\n\nGenerated Query:\n".format(prompt_template, user_input)
    query_string = query_langchain(llm, prompt)

    print('INITIAL QUERY:\n {}\n\n'.format(query_string))
    error_message, hits_list = query_graphql(query_string)
    runs = 0
    
    while error_message:
        if 'syntaxError' not in error_message:
            # if its not a syntax error, we can ask GPT for suggestions
            prompt = "Given a query, error message and schema, generate a suggestion on how the query can be improved in natural language citing specific fields within the schema. Generate only a suggestion, not a query.\nSchema:\n{} \nQuery:\n{}\nError Message:\n{}Suggestion:\n".format(schema, query_string, error_message)
            suggestion = query_chatgpt_16k(prompt)
            # print(suggestion)
            prompt = "The query failed with the following error: {}\n Here is a suggestion on how to correct the query. {} Can you regenerate the query to fix the error? \nRegenerated Query:\n".format(error_message, suggestion)
        
        else:
            # suggestions on syntax errors confuse the model
            prompt = "The query failed with the following error: {}\n Can you regenerate the query to fix the error? \nRegenerated Query:\n".format(error_message)
        query_string = query_langchain(llm, prompt)
        error_message, hits_list = query_graphql(query_string)
        runs+=1
        if runs==20:
            error_message=None
            break

    response_text = convert_json_response(hits_list, user_input)    
    print(hits_list)
    print('ANSWER:\n{}'.format(response_text))
# Out:
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find the top 2 diseases linked to HBB
#
# INITIAL QUERY:
#   query top_n_associated_diseases {
#     search(queryString: "HBB", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 2}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# {'id': 'ENSG00000244734', 'name': 'HBB', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.793993706260743, 'disease': {'name': 'beta-thalassemia HBB/LCRB'}}, {'score': 0.774931251992265, 'disease': {'name': 'sickle cell anemia'}}]}}}
# ANSWER:
# 1. Beta-thalassemia HBB/LCRB
# 2. Sickle cell anemia
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the top 3 diseases associated with ABCA4?
#
# INITIAL QUERY:
#   query top_n_associated_diseases {
#     search(queryString: "ABCA4", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases(page: {index: 0, size: 3}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# {'id': 'ENSG00000198691', 'name': 'ABCA4', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.8341689198627416, 'disease': {'name': 'severe early-childhood-onset retinal dystrophy'}}, {'score': 0.8288074666259394, 'disease': {'name': 'Cone rod dystrophy'}}, {'score': 0.7835075940441717, 'disease': {'name': 'age-related macular degeneration'}}]}}}
# ANSWER:
# - Severe early-childhood-onset retinal dystrophy
# - Cone rod dystrophy
# - Age-related macular degeneration
# ----------------------------------------------------------------------------------------------------
# USER INPUT: What are the targets of vorinostat?
#
# INITIAL QUERY:
#   query targets_of_vorinostat {
#     search(queryString: "vorinostat", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               targets {
#                  rows {
#                   score
#                    target {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Cannot query field 'targets' on type 'Target'. (line 8, column 15):
#               targets {
#               ^
#
#
# ERROR:
#  Cannot query field 'associatedTargets' on type 'Target'. Did you mean 'associatedDiseases'? (line 8, column 15):
#               associatedTargets {
#               ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'AssociatedDisease'. (line 11, column 20):
#                    target {
#                    ^
#
#
# ERROR:
#  Cannot query field 'target' on type 'Disease'. (line 13, column 22):
#                      target {
#                      ^
#
#
# {'id': 'ENSG00000171720', 'name': 'HDAC3', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.5669897715700565, 'disease': {'name': 'neoplasm'}}, {'score': 0.5397429909321528, 'disease': {'name': 'multiple myeloma'}}, {'score': 0.5281167797105957, 'disease': {'name': 'neurodegenerative disease'}}, {'score': 0.5161689514662866, 'disease': {'name': 'unspecified peripheral T-cell lymphoma'}}, {'score': 0.5112367470391775, 'disease': {'name': 'Cutaneous T-cell lymphoma'}}, {'score': 0.5039631962908891, 'disease': {'name': 'T-cell non-Hodgkin lymphoma'}}, {'score': 0.3921652902487669, 'disease': {'name': 'graft versus host disease'}}, {'score': 0.38292579388164927, 'disease': {'name': 'primary myelofibrosis'}}, {'score': 0.380262012567663, 'disease': {'name': 'viral disease'}}, {'score': 0.3701210148708717, 'disease': {'name': 'lymphoma'}}, {'score': 0.35761793906626343, 'disease': {'name': 'acute myeloid leukemia'}}, {'score': 0.3531540833653817, 'disease': {'name': 'genetic disorder'}}, {'score': 0.35023083627462015, 'disease': {'name': 'breast adenocarcinoma'}}, {'score': 0.3359891523366922, 'disease': {'name': 'lung cancer'}}, {'score': 0.3169137366531992, 'disease': {'name': 'breast cancer'}}, {'score': 0.31163268183323867, 'disease': {'name': 'renal cell carcinoma'}}, {'score': 0.29668129877261334, 'disease': {'name': 'Hodgkins lymphoma'}}, {'score': 0.28898321456898174, 'disease': {'name': 'ovarian cancer'}}, {'score': 0.28624931542943366, 'disease': {'name': 'head and neck squamous cell carcinoma'}}, {'score': 0.27835937669378524, 'disease': {'name': 'endometrial cancer'}}, {'score': 0.27718489101352634, 'disease': {'name': 'mesothelioma'}}, {'score': 0.26959461007668845, 'disease': {'name': 'gastric adenocarcinoma'}}, {'score': 0.25907547813397597, 'disease': {'name': 'angioimmunoblastic T-cell lymphoma'}}, {'score': 0.2231338372658887, 'disease': {'name': 'squamous cell lung carcinoma'}}, {'score': 0.20891842845958888, 'disease': {'name': 'small cell lung carcinoma'}}]}}}
# ANSWER:
# The targets of vorinostat are:
# 1. HDAC3
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Find drugs that are used for treating ulcerative colitis.
#
# INITIAL QUERY:
#   query drugs_for_ulcerative_colitis {
#     search(queryString: "ulcerative colitis", entityNames: "drug") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Drug {
#               indications(page: {index: 0, size: 5}) {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Unknown argument 'page' on field 'indications' of type 'Drug'. (line 8, column 27):
#               indications(page: {index: 0, size: 5}) {
#                           ^
#
#
# ERROR:
#  Cannot query field 'score' on type 'IndicationRow'. (line 10, column 19):
#                   score
#                   ^
#
#
# {'id': 'CHEMBL1200760', 'name': 'BALSALAZIDE DISODIUM', 'entity': 'drug', 'object': {'indications': {'rows': [{'disease': {'name': 'ulcerative colitis'}}]}}}
# ANSWER:
# - BALSALAZIDE DISODIUM
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Which diseases are associated with the genes targetted by fasudil?
#
# INITIAL QUERY:
#   query associated_diseases {
#     search(queryString: "fasudil", entityNames: "target") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Target {
#               associatedDiseases {
#                  rows {
#                   score
#                    disease {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
#
#
# {'id': 'ENSG00000134318', 'name': 'ROCK2', 'entity': 'target', 'object': {'associatedDiseases': {'rows': [{'score': 0.5580112081648932, 'disease': {'name': 'open-angle glaucoma'}}, {'score': 0.5570338462445541, 'disease': {'name': 'ocular hypertension'}}, {'score': 0.5478429832481734, 'disease': {'name': 'neurodegenerative disease'}}, {'score': 0.5052279849309224, 'disease': {'name': 'glaucoma'}}, {'score': 0.4715736284706049, 'disease': {'name': 'graft versus host disease'}}, {'score': 0.46605046286448354, 'disease': {'name': 'Fuchs endothelial corneal dystrophy'}}, {'score': 0.40047013678235266, 'disease': {'name': 'mean corpuscular volume'}}, {'score': 0.3761867338373383, 'disease': {'name': 'lymphocyte count'}}, {'score': 0.37367454435923936, 'disease': {'name': 'body height'}}, {'score': 0.3720764692641677, 'disease': {'name': 'myocardial infarction'}}, {'score': 0.3695798546847018, 'disease': {'name': 'low tension glaucoma'}}, {'score': 0.3695798546847018, 'disease': {'name': 'immune system disease'}}, {'score': 0.34449779007508613, 'disease': {'name': 'BMI-adjusted waist-hip ratio'}}, {'score': 0.32747009105961955, 'disease': {'name': 'body fat percentage'}}, {'score': 0.32464439018738533, 'disease': {'name': 'platelet component distribution width'}}, {'score': 0.3201710930473081, 'disease': {'name': 'mean reticulocyte volume'}}, {'score': 0.31328473619297864, 'disease': {'name': 'brain measurement'}}, {'score': 0.31282878665806985, 'disease': {'name': 'cortical thickness'}}, {'score': 0.29525093859405127, 'disease': {'name': 'serum gamma-glutamyl transferase measurement'}}, {'score': 0.27755447086821106, 'disease': {'name': 'cardiovascular disease'}}, {'score': 0.27718489101352634, 'disease': {'name': 'corneal edema'}}, {'score': 0.26644582337094425, 'disease': {'name': 'appendicular lean mass'}}, {'score': 0.2660512016698931, 'disease': {'name': 'low density lipoprotein cholesterol measurement'}}, {'score': 0.2658871320913831, 'disease': {'name': 'basal cell carcinoma'}}, {'score': 0.262697269669774, 'disease': {'name': 'creatinine measurement'}}]}}}
# ANSWER:
# - Open-angle glaucoma
# - Ocular hypertension
# - Neurodegenerative disease
# - Glaucoma
# - Graft versus host disease
# - Fuchs endothelial corneal dystrophy
# - Mean corpuscular volume
# - Lymphocyte count
# - Body height
# - Myocardial infarction
# - Low tension glaucoma
# - Immune system disease
# - BMI-adjusted waist-hip ratio
# - Body fat percentage
# - Platelet component distribution width
# - Mean reticulocyte volume
# - Brain measurement
# - Cortical thickness
# - Serum gamma-glutamyl transferase measurement
# - Cardiovascular disease
# - Corneal edema
# - Appendicular lean mass
# - Low density lipoprotein cholesterol measurement
# - Basal cell carcinoma
# - Creatinine measurement
# ----------------------------------------------------------------------------------------------------
# USER INPUT: Show all the diseases that have at least 5 pathways associated with Alzheimer
#
# INITIAL QUERY:
#   query all_diseases_with_5_pathways {
#     search(queryString: "Alzheimer", entityNames: "disease") {
#     hits { id,
#            name,
#            entity,
#             object {
#                ... on Disease {
#               associatedPathways(page: {index: 0, size: 5}) {
#                  rows {
#                   score
#                    pathway {
#                      name
#                        }
#                     }
#                 }
#             }
#         }
#      }
#    }
#  }
# }
#
#
# ERROR:
#  {'syntaxError': "Syntax error while parsing GraphQL query. Invalid input '}', expected ExecutableDefinition or TypeSystemDefinition (line 21, column 1):\n}\n^", 'locations': [{'line': 21, 'column': 1}]}
#
#
# ERROR:
#  Cannot query field 'associatedPathways' on type 'Disease'. Did you mean 'associatedTargets'? (line 8, column 15):
#               associatedPathways(page: {index: 0, size: 5}) {
#               ^
#
#
# ERROR:
#  Cannot query field 'name' on type 'Target'. (line 12, column 22):
#                      name
#                      ^
#
#
# ERROR:
#  Cannot query field 'symbol' on type 'Target'. (line 13, column 22):
#                      symbol
#                      ^
#
#
# ERROR:
#  Cannot query field 'description' on type 'Target'. (line 13, column 22):
#                      description
#                      ^
#
#
# {'id': 'MONDO_0004975', 'name': 'Alzheimer disease', 'entity': 'disease', 'object': {'associatedTargets': {'rows': [{'score': 0.828933742802346, 'target': {'id': 'ENSG00000142192'}}, {'score': 0.7241430601388238, 'target': {'id': 'ENSG00000080815'}}, {'score': 0.6972811478504712, 'target': {'id': 'ENSG00000176884'}}, {'score': 0.6794149794175904, 'target': {'id': 'ENSG00000164885'}}, {'score': 0.6788101271141604, 'target': {'id': 'ENSG00000143801'}}]}}}
# ANSWER:
# - Alzheimer disease
